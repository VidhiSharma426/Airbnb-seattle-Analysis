# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('listings.csv')

# %%
df.head()
# Out:
#      id                                        name  host_id  host_name  \
# 0  6606         Fab, private seattle urban cottage!    14942      Joyce
# 1  9419         Glorious sun room w/ memory foambed    30559  Angielena
# 2  9531         The Adorable Sweet Orange Craftsman    31481     Cassie
# 3  9534            The Coolest Tangerine Dream MIL!    31481     Cassie
# 4  9596  the down home , spacious, central and fab!    14942      Joyce
#
#    neighbourhood_group   neighbourhood  latitude  longitude        room_type  \
# 0  Other neighborhoods     Wallingford  47.65444 -122.33629  Entire home/apt
# 1  Other neighborhoods      Georgetown  47.55017 -122.31937     Private room
# 2         West Seattle  Fairmount Park  47.55495 -122.38663  Entire home/apt
# 3         West Seattle  Fairmount Park  47.55627 -122.38607  Entire home/apt
# 4  Other neighborhoods     Wallingford  47.65608 -122.33602  Entire home/apt
#
# ...

# %%
df.shape
# Out:
# (6442, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6442 entries, 0 to 6441
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              6442 non-null   int64
#  1   name                            6442 non-null   object
#  2   host_id                         6442 non-null   int64
#  3   host_name                       6442 non-null   object
#  4   neighbourhood_group             6442 non-null   object
#  5   neighbourhood                   6442 non-null   object
#  6   latitude                        6442 non-null   float64
#  7   longitude                       6442 non-null   float64
#  8   room_type                       6442 non-null   object
#  9   price                           6011 non-null   float64
#  10  minimum_nights                  6442 non-null   int64
#  11  number_of_reviews               6442 non-null   int64
# ...

# %%
df.describe()
# Out:
#                  id       host_id     latitude    longitude        price  \
# count  6.442000e+03  6.442000e+03  6442.000000  6442.000000  6011.000000
# mean   4.778906e+17  1.561396e+08    47.626021  -122.334359   212.495092
# std    4.635029e+17  1.730557e+08     0.048794     0.033425   222.397718
# min    6.606000e+03  4.193000e+03    47.495874  -122.419040    10.000000
# 25%    3.418163e+07  1.987743e+07    47.601655  -122.357278   116.000000
# 50%    6.144249e+17  8.033375e+07    47.623220  -122.332260   167.000000
# 75%    9.319134e+17  2.552755e+08    47.663776  -122.310931   250.000000
# max    1.185488e+18  5.848754e+08    47.734087  -122.240870  9000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count     6442.000000        6442.000000        5601.000000
# mean        11.127134          74.720584           2.264496
# std         18.466967         114.938072           2.572886
# min          1.000000           0.000000           0.010000
# ...

# %%
df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                              431
# minimum_nights                       0
# number_of_reviews                    0
# last_review                        841
# reviews_per_month                  841
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           1130
# dtype: int64

# %%
df[df['price'].isnull()]
# Out:
#                        id                                               name  \
# 4                    9596         the down home , spacious, central and fab!
# 6                   37234  Your Home Away From Home.  Private Parking ons...
# 19                 340706                     Charming Wallingford Apartment
# 22                 356248        Amazing Waterview Condo near UW + Eastlake!
# 25                 368403                 Large Luxury Lakeside Seattle Home
# ...                   ...                                                ...
# 6251  1152716284962819261          Mini Full | City Access & Panoramic Views
# 6253  1152716387472686024  Modern Queen | Downtown, Original Art, City Views
# 6254  1152726470142663972  Central Location | Exclusive Vinyl Set & City ...
# 6287  1157183608078577972    Blueground | Downtown, gym & roof, nr nightlife
# 6302  1160322044129353646                          Garden Artist Loft Studio
#
# ...

# %%
df[df['reviews_per_month'].isnull()]
# Out:
#                        id                                              name  \
# 20                 340738                    Victorian home on Capitol Hill
# 272               4630355                       Luxury Penthouse in Seattle
# 541              10834487                                       Corner room
# 554              11254431                      Master suite in Ballard home
# 638              13081598            Urban Classic Lake Union & City center
# ...                   ...                                               ...
# 6437  1183589253922277689   Ballard Vintage: Prime location | Newly updated
# 6438  1183592829252603312                 Near UW&Seattle children Hospital
# 6439  1184105202783807108                                The Lavender House
# 6440  1184121064141612057                     King bed near lake Washington
# 6441  1185488158015572994  Luxurious 2BR Penthouse with Water View Seattle!
#
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
import numpy as nd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df1=df.groupby('neighbourhood_group')['id'].count().reset_index()

# %%
df1
# Out:
#     neighbourhood_group    id
# 0               Ballard   411
# 1           Beacon Hill   260
# 2          Capitol Hill   581
# 3               Cascade   261
# 4          Central Area   605
# 5              Delridge   195
# 6              Downtown   831
# 7              Interbay    15
# 8             Lake City   110
# 9              Magnolia   105
# 10            Northgate   199
# 11  Other neighborhoods  1249
# 12           Queen Anne   474
# 13       Rainier Valley   362
# 14          Seward Park    52
# 15  University District   268
# 16         West Seattle   464

# %%
plt.figure(figsize=(12, 12))  # Optional: Set the figure size
plt.bar(df1['neighbourhood_group'], df1['id'], color='skyblue')
plt.title('count by Neighbourhood', fontsize=16)
plt.xlabel('Neighbourhood', fontsize=12)
plt.ylabel('count', fontsize=12)
plt.xticks(rotation=45)  # Rotate the x-axis labels for better readability

# Show the plot
plt.show()

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
df2=df.groupby('neighbourhood')['id'].count().reset_index()

# %%
df2
# Out:
#        neighbourhood   id
# 0              Adams  126
# 1               Alki  117
# 2      Arbor Heights   24
# 3           Atlantic  131
# 4           Belltown  343
# ..               ...  ...
# 83     West Woodland  113
# 84          Westlake   18
# 85  Whittier Heights   70
# 86        Windermere   14
# 87    Yesler Terrace   69
#
# [88 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
df3=df.groupby('room_type')['id'].count().reset_index()

# %%
df3
# Out:
#          room_type    id
# 0  Entire home/apt  5387
# 1       Hotel room    21
# 2     Private room  1024
# 3      Shared room    10

# %%
plt.figure(figsize=(10, 12))  # Optional: Set the figure size
plt.bar(df3['room_type'], df3['id'], color='skyblue')
plt.title('count by room type', fontsize=16)
plt.xlabel('room type', fontsize=12)
plt.ylabel('count', fontsize=12)
plt.xticks(rotation=45)  # Rotate the x-axis labels for better readability

# Show the plot
plt.show()

# %%
df4=df.groupby('number_of_reviews')['id'].count().reset_index().head(30)

# %%
plt.figure(figsize=(10, 12))  # Optional: Set the figure size
plt.bar(df4['number_of_reviews'], df4['id'], color='skyblue')
plt.title('count by number of reviews', fontsize=16)
plt.xlabel('Number of reviews', fontsize=12)
plt.ylabel('count', fontsize=12)
plt.xticks(rotation=45)  # Rotate the x-axis labels for better readability

# Show the plot
plt.show()

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
df['last_review']=pd.to_datetime(df['last_review'])

# %%
df['last_review_month']=df['last_review'].dt.month_name()

# %%
df5=df.groupby('last_review_month')['number_of_reviews'].count().reset_index()

# %%
df5
# Out:
#    last_review_month  number_of_reviews
# 0              April                245
# 1             August                167
# 2           December                107
# 3           February                106
# 4            January                128
# 5               July                 99
# 6               June               3332
# 7              March                173
# 8                May                771
# 9           November                123
# 10           October                147
# 11         September                203

# %%
plt.figure(figsize=(8,8 ))  # Optional: Set the figure size
plt.bar(df5['last_review_month'], df5['number_of_reviews'], color='skyblue')
plt.title('count by number of reviews', fontsize=16)
plt.xlabel('Number of reviews', fontsize=12)
plt.ylabel('count', fontsize=12)
plt.xticks(rotation=45)  # Rotate the x-axis labels for better readability

# Show the plot
plt.show()

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license',
#        'last_review_month'],
#       dtype='object')

# %%
df['last_review_YEAR']=df['last_review'].dt.year

# %%
df6=df.groupby('last_review_YEAR')['number_of_reviews'].count().reset_index()

# %%
df6
# Out:
#    last_review_YEAR  number_of_reviews
# 0            2015.0                  3
# 1            2016.0                  6
# 2            2017.0                  5
# 3            2018.0                 16
# 4            2019.0                 40
# 5            2020.0                 28
# 6            2021.0                 54
# 7            2022.0                178
# 8            2023.0                720
# 9            2024.0               4551

# %%
plt.figure(figsize=(6,6 ))  # Optional: Set the figure size
plt.bar(df6['last_review_YEAR'], df6['number_of_reviews'], color='skyblue')
plt.title('count by number of reviews', fontsize=16)
plt.xlabel('Number of reviews', fontsize=12)
plt.ylabel('count', fontsize=12)
plt.xticks(rotation=45)  # Rotate the x-axis labels for better readability

# Show the plot
plt.show()

# %%
df7=df.groupby(['calculated_host_listings_count'])['id'].count().reset_index().head(10)

# %%
df7
# Out:
#    calculated_host_listings_count    id
# 0                               1  2585
# 1                               2   840
# 2                               3   387
# 3                               4   236
# 4                               5   170
# 5                               6   198
# 6                               7   105
# 7                               8   104
# 8                               9    54
# 9                              10   100

# %%
# Sorting the data by 'id' in descending order for bar chart
df_sorted_desc = df7.sort_values('id', ascending=False)

# Create the bar chart with the sorted data
plt.figure(figsize=(8, 6))
plt.bar(df_sorted_desc['calculated_host_listings_count'], df_sorted_desc['id'], color='lightcoral')

# Add labels and title
plt.title('Bar Chart of Listings Sorted by ID ', fontsize=16)
plt.xlabel('Calculated Host Listings Count', fontsize=12)
plt.ylabel('ID Values', fontsize=12)

# Display the plot
plt.show()

# %%
import seaborn as sns
sns.histplot(x='availability_365', data=df,kde=True,color='lightcoral')
# Out:
# <Axes: xlabel='availability_365', ylabel='Count'>

# %%
df8=df.groupby('room_type')['price'].mean().reset_index()

# %%
plt.figure(figsize=(8, 6))
plt.bar(df8['room_type'], df8['price'], color='lightcoral')

# Add labels and title
plt.title('Bar Chart of room type Sorted by ID ', fontsize=16)
plt.xlabel('Calculated room type', fontsize=12)
plt.ylabel('Average Price', fontsize=12)

# Display the plot
plt.show()

# %%
df9=df.groupby('neighbourhood_group')['minimum_nights'].mean().reset_index()

# %%
df9
# Out:
#     neighbourhood_group  minimum_nights
# 0               Ballard       10.754258
# 1           Beacon Hill        8.907692
# 2          Capitol Hill       15.156627
# 3               Cascade       22.793103
# 4          Central Area       11.039669
# 5              Delridge       10.441026
# 6              Downtown       11.172082
# 7              Interbay       17.800000
# 8             Lake City        9.000000
# 9              Magnolia        9.095238
# 10            Northgate       12.321608
# 11  Other neighborhoods        9.336269
# 12           Queen Anne        8.831224
# 13       Rainier Valley        7.110497
# 14          Seward Park        9.153846
# 15  University District       17.111940
# 16         West Seattle        8.715517

# %%
plt.figure(figsize=(8, 6))
plt.bar(df9['neighbourhood_group'], df9['minimum_nights'], color='lightcoral')

# Add labels and title
plt.title('Bar Chart of room type Sorted by ID ', fontsize=16)
plt.xlabel('Calculated neighbourhood_group', fontsize=12)
plt.ylabel('Average minimum nights', fontsize=12)
plt.xticks(rotation=45)
# Display the plot
plt.show()

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license',
#        'last_review_month', 'last_review_YEAR'],
#       dtype='object')

# %%
df10=df.groupby('neighbourhood_group')['number_of_reviews'].mean().reset_index()

# %%
plt.figure(figsize=(8, 6))
plt.bar(df10['neighbourhood_group'], df10['number_of_reviews'], color='lightcoral')

# Add labels and title
plt.title('Average number of reviews by neighbourhood group', fontsize=16)
plt.xlabel('Calculated neighbourhood_group', fontsize=12)
plt.ylabel('Average number of reviews', fontsize=12)
plt.xticks(rotation=35)
# Display the plot
plt.show()

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license',
#        'last_review_month', 'last_review_YEAR'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('reviews.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-60-84c49bb55334> in <cell line: 1>()
# ----> 1 data = pd.read_csv('reviews.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     946     kwds.update(kwds_defaults)
#     947
# ...

# %%
data.head()

# %%
data.shape

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')

# %%
pip install nltk

# %%
data.dropna(inplace=True)

# %%
data

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(stop_words='english')
words = cv.fit_transform(data['comments'])

# %%
words

# %%
data.isnull().sum()

# %%
data.dropna(inplace=True)

# %%
import nltk
from nltk.stem import PorterStemmer

# Initialize the Porter Stemmer
stemmer = PorterStemmer()

# %%
import nltk

# Specify the directory for NLTK data
nltk.data.path.append('C:\\Users\\hp\\Downloads\\advertising\\reviews.csv')

# %%
data.head()

# %%
top_10_hosts=data['listing_id'].value_counts().reset_index().head(10)

# %%
top_10_hosts

# %%
merged_df = pd.merge(top_10_hosts, df, left_on='listing_id', right_on='id', how='left')

print("Merged DataFrame:")

# %%
merged_df['listing_id']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(7, 7))  # Optional, to adjust the figure size
plt.pie(merged_df['count'], colors = ['#FFDAB9', '#FFB6C1', '#FFA07A', '#FF7F7F', '#F08080',
          '#FA8072', '#FF6F61', '#FF6347', '#FF4500', '#E9967A'],labels=merged_df['name'], autopct='%1.1f%%', shadow=True, startangle=140)
plt.show()

# %%
dd=data[data['listing_id']==3861673]['comments']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# Combine all filtered comments into a single text
filtered_comments_text = ' '.join(dd)

# Create a word cloud from the filtered comments
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(filtered_comments_text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Assuming your DataFrame is named `data`

# List of listing_ids
listing_ids = [25002, 11398085, 12929985, 7462250, 21080282, 365550, 3543247, 3022564, 19699462]

# Filter the comments for the given listing_ids
filtered_comments = data[data['listing_id'].isin(listing_ids)]['comments']

# Combine all the filtered comments into a single string
all_filtered_comments = ' '.join(filtered_comments)

# Create the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_filtered_comments)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")  # Hide the axes
plt.show()

# %%
bottom_10_hosts=data['listing_id'].value_counts().reset_index().tail(40)

# %%
bottom_10_hosts

# %%
bottom_10_hosts['listing_id']

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Assuming your DataFrame is named `data`

# List of listing_ids
listing_ids = [1407502, 1589732, 3770248, 4165554, 1807936, 1175308, 661708, 229990, 1603124, 3679617,
               2847177, 1647216, 598023, 3273014, 5104918, 4263136, 1150519, 1935439, 1136522, 3505829,
               689309, 2614238, 620518, 671828, 303277, 1629525, 3441487, 670262, 3022308, 4113197,
               993804, 1263470, 850481, 37234, 4892357, 1305895, 1696389, 3652078, 4550535, 1142010]

# Filter the comments for the given listing_ids
filtered_comments = data[data['listing_id'].isin(listing_ids)]['comments']

# Combine all the filtered comments into a single string
all_filtered_comments = ' '.join(filtered_comments)

# Create the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_filtered_comments)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")  # Hide the axes
plt.show()

# %%
import folium
import pandas as pd

# Create a Folium map object centered at the average of the provided points
m = folium.Map(location=[df['latitude'].mean(), df['longitude'].mean()], zoom_start=5)

# Add markers for each point
for i, row in df.iterrows():
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=10,  # Radius of the circle
        color='red',
        fill=True,
        fill_color='lightcoral'
    ).add_to(m)

# Save the map to an HTML file and display it
m.save("map.html")

# To display the map directly in Jupyter Notebook, you can use the following:
m

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license',
#        'last_review_month', 'last_review_YEAR'],
#       dtype='object')

# %%
df['occupancy_rate']= (365-df['availability_365'])/365

# %%
data2=df.groupby('room_type')['price'].mean().reset_index()

# %%
df['net_revenue']=df['price']*(365-df['availability_365'])

# %%
df['net_revenue']
# Out:
# 0       21582.0
# 1        2128.0
# 2       43848.0
# 3       45500.0
# 4           NaN
#          ...
# 6437    19721.0
# 6438    27798.0
# 6439    43068.0
# 6440     4200.0
# 6441    92016.0
# Name: net_revenue, Length: 6442, dtype: float64

# %%
avg_min_nights=df['minimum_nights'].mean()

# %%
df['host_review_score']=df['number_of_reviews']/df['calculated_host_listings_count']

# %%
data3=df['last_review_YEAR'].value_counts().reset_index()

# %%
total=data3['count'].sum()

# %%
data3['Percentage'] = (data3['count'] / total) * 100

# %%
data3
# Out:
#    last_review_YEAR  count  Percentage
# 0            2024.0   4551   81.253348
# 1            2023.0    720   12.854847
# 2            2022.0    178    3.178004
# 3            2021.0     54    0.964114
# 4            2019.0     40    0.714158
# 5            2020.0     28    0.499911
# 6            2018.0     16    0.285663
# 7            2016.0      6    0.107124
# 8            2017.0      5    0.089270
# 9            2015.0      3    0.053562

# %%
data4=df.groupby('last_review_YEAR')['net_revenue'].mean().reset_index()

# %%
data4['Revenue_Growth_Rate'] = data4['net_revenue'].pct_change() * 100

# %%
plt.figure(figsize=(10, 5))

# Plot Revenue
plt.plot(data4['last_review_YEAR'], data4['net_revenue'], marker='o', label='Revenue', color='b')

# Plot Revenue Growth Rate
plt.plot(data4['last_review_YEAR'], data4['Revenue_Growth_Rate'], marker='o', label='Revenue Growth Rate (%)', color='g')

# Adding titles and labels
plt.title('Revenue and Revenue Growth Rate Over Time')
plt.xlabel('Year')
plt.ylabel('Value')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license',
#        'last_review_month', 'last_review_YEAR', 'occupancy_rate',
#        'net_revenue', 'host_review_score'],
#       dtype='object')

# %%
data5=df.groupby('neighbourhood_group')['calculated_host_listings_count'].mean().reset_index()

# %%
data5=df.groupby('last_review_YEAR')['number_of_reviews'].mean().reset_index()

# %%
data5['pct_chnge_qty']=data5['number_of_reviews'].pct_change() * 100

# %%
data5['price_elasticity'] = data5['pct_chnge_qty'] / data4['Revenue_Growth_Rate']

# %%
data5
# Out:
#    last_review_YEAR  number_of_reviews  pct_chnge_qty  price_elasticity
# 0            2015.0          23.666667            NaN               NaN
# 1            2016.0          10.500000     -55.633803          0.747161
# 2            2017.0          29.800000     183.809524          1.313035
# 3            2018.0           8.687500     -70.847315          1.948947
# 4            2019.0          54.200000     523.884892         61.146902
# 5            2020.0          90.321429      66.644702         -2.121453
# 6            2021.0          50.944444     -43.596503         11.999008
# 7            2022.0          26.606742     -47.773026         -0.724619
# 8            2023.0          34.358333      29.133939         -3.445921
# 9            2024.0          97.562294     183.955258         17.246746

# %%
data6=df.groupby('room_type')['number_of_reviews'].mean().reset_index()

# %%
data6

# %%
data7=df.groupby('room_type')['price'].mean().reset_index()

# %%
data7
# Out:
#          room_type       price
# 0  Entire home/apt  231.411544
# 1       Hotel room  548.200000
# 2     Private room  102.826464
# 3      Shared room   82.700000

# %%
plt.figure(figsize=(10, 5))

# Plot Revenue
# plt.plot(data7['room_type'], data7['price'], marker='o', label='price', color='b')

# Plot Revenue Growth Rate
plt.plot(data7['room_type'], data7['price'], marker='o', label='price chnage', color='g')

# Adding titles and labels
plt.title('price change by room type')
plt.xlabel('room type')
plt.ylabel('Value')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
data8=df.groupby('neighbourhood_group')['price'].mean().reset_index()

# %%
plt.figure(figsize=(10, 5))

# Plot Revenue
# plt.plot(data7['room_type'], data7['price'], marker='o', label='price', color='b')

# Plot Revenue Growth Rate
plt.plot(data8['neighbourhood_group'], data8['price'], marker='o', label='price chnage', color='g')

# Adding titles and labels
plt.title('price change by neighbourhood_group')
plt.xlabel('room type')
plt.ylabel('Value')
plt.legend()
plt.xticks(rotation=435)

# Show the plot
plt.grid(True)
plt.show()

# %%
host_avg_reviews = df.groupby('host_id')['reviews_per_month'].mean().reset_index()

# Merge with availability_365
host_info = df[['host_id', 'availability_365']].drop_duplicates()
host_avg_reviews = host_avg_reviews.merge(host_info, on='host_id')

# Sort hosts by highest average reviews per month and lowest availability_365
top_hosts = host_avg_reviews.sort_values(by=['reviews_per_month', 'availability_365'], ascending=[False, True])

print(top_hosts.head(10))
# Out:
#         host_id  reviews_per_month  availability_365
# 5694  569419884          59.533333               134
# 5695  569419884          59.533333               155
# 5696  569419884          59.533333               158
# 5050  437880135          15.560000                50
# 4330  240730356          13.510000               117
# 1477   18141906          12.000000                 3
# 3805  137418982          11.820000                37
# 3804  137418982          11.820000               155
# 1542   19928221          11.740000               216
# 4741  380578321          11.290000               274

# %%
df.columns
